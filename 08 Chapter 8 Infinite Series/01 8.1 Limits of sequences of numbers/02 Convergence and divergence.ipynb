# %% [markdown]
# # Convergence and divergence
# As Fig. 8.1 shows, the sequences of Example 1 do not behave the same way. The sequences $\{1/n\}$, $\{(-1)^{n+1}(1/n)\}$, and $\{(n-1)/n\}$ each seem to approach a single limiting value as $n$ increases, and $\{3\}$ is at a limiting value from the very first. On the other hand, terms $\{(-1)^{n+1}(n-1)/n\}$ seem to accumulate near two different values, $-1$ and $1$, while th terms of $\{\sqrt{n}\}$ become increasingly large and do not accumulate anywhere.
#
# To distinguish sequences that approach a unique limiting value $L$, as $n$ increases, from those that do not, we say that the former sequences _converge_, according to the following definition.

# %% [markdown]
# ## Definitions
# The sequence $\{a_n\}$ __converges__ to the number $L$ if to every positive number $\epsilon$ there corresponds an integer $N$ such that for all $n$,
#
# $$
# \begin{align}
# n>N \ \ \ \ \ \ \ \  \Rightarrow \ \ \ \ \ \ \ \ |a_n-L|<\epsilon\text{.}
# \end{align}
# $$
#
# If no such number $L$ exists, we say that $\{a_n\}$ __diverges__.
#
# If $\{a_n\}$ converges to $L$, we write $\lim_{n\rightarrow\infty}{a_n}=L$, or simply $a_n \rightarrow L$, and call $L$ the __limit__ of the sequence (Fig. 8.2).

# %% [markdown]
# ### EXAMPLE 2 &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;  Testing the definition
# Show that
#
# __a)__  $\lim_{n \rightarrow \infty}{\frac{1}{n}}=0$
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# __b)__  $\lim_{n \rightarrow \infty}{k}=k$ (any constant $k$)
#
# ### Solution
# __a)__ Let $\epsilon > 0$ be given. We must show that exists an integer $N$ such that for all $n$,
#
# $$
# \begin{align}
# n>N \ \ \ \ \ \ \ \ \Rightarrow \ \ \ \ \ \ \ \ \left\lvert \frac{1}{n} - 0 \right\rvert < \epsilon\text{.}
# \end{align}
# $$
#
# This implication will hold if $(1/n) < \epsilon$ or $n > 1/\epsilon$. If $N$ is any integer greater than $1/\epsilon$, the implication will hold for all $n>N$. This proves that $\lim_{n\to\infty}{(1/n)}=0$.
#
# __b)__ Let $\epsilon > 0$ be given. We must show that there exists an integer $N$ such that for all $n$,
#
# $$
# \begin{align}
# n>N \ \ \ \ \ \ \ \ \Rightarrow \ \ \ \ \ \ \ \ \left\lvert k-k \right\rvert < \epsilon\text{.}
# \end{align}
# $$
#
# Since $k-k=0$, we can use any positive ingeger for $N$ and the implication will hold. This proves that $\lim_{n\to\infty}{k}=k$ for any constant $k$.
